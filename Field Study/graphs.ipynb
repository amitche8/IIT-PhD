# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_T_Complete Data_model.xlsx")

t = df['Hour']
t_o_t = df['Avg T']
t_o_it = df['Avg IT']
t_o_mt = df['Modeled']

fig, axs = plt.subplots(1, 1, layout='constrained', figsize=(7,6))
axs.plot(t, t_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs.plot(t, t_o_it, linewidth=1, color = 'red', label='Monitored Temp')
axs.plot(t, t_o_mt, linewidth=2, color= 'orange', label='Modeled Temp')



# axs[0].set_xlim(0, 2)
axs.set_xlabel('Hour')
# axs[1].set_xlabel('Date')
# axs[2].set_xlabel('Date')
axs.set_ylabel('Temperature [°C]')

axs.grid(True)

axs.legend(loc='lower left', fontsize=6)

axs.axvspan(114, 161, facecolor='b', alpha=0.2)



# plt.setp(axs[2].xaxis.get_majorticklabels(), rotation=30)
plt.suptitle('House T Calibration')
plt.show()

# %%
df = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_A_Complete Data.xlsx")

t = df['Date-Time (CDT)']
a_o_t = df['A_O_T [°C]']
a_1_n_t = df['A_1_N_T  [°C]']
a_1_s_t = df['A_1_S_T  [°C]']
a_2_n_t = df['A_2_N_T  [°C]']
a_2_s_t = df['A_2_S_T  [°C]']
a_3_n_t = df['A_3_N_T  [°C]']
a_3_s_t = df['A_3_S_T  [°C]']


a_1_n_mrt = df['A_1_N_MRT  [°C]']
a_1_s_mrt = df['A_1_S_MRT  [°C]']
a_2_n_mrt = df['A_2_N_MRT  [°C]']
a_2_s_mrt = df['A_2_S_MRT  [°C]']
a_3_n_mrt = df['A_3_N_MRT  [°C]']
a_3_s_mrt = df['A_3_S_MRT  [°C]']

a_o_rh = df['A_O_RH [%]']
a_1_n_rh = df['A_1_N_RH  [%]']
a_1_s_rh = df['A_1_S_RH  [%]']
a_2_n_rh = df['A_2_N_RH  [%]']
a_2_s_rh = df['A_2_S_RH  [%]']
a_3_n_rh = df['A_3_N_RH  [%]']
a_3_s_rh = df['A_3_S_RH  [%]']

fig, axs = plt.subplots(3, 1, layout='constrained', figsize=(6,8))
axs[0].plot(t, a_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[0].plot(t, a_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement N')
axs[0].plot(t, a_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement S')
axs[0].plot(t, a_2_n_t, linewidth=0.6, color= 'mediumblue', label='First N')
axs[0].plot(t, a_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First S')
axs[0].plot(t, a_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second N')
axs[0].plot(t, a_3_s_t, linewidth=0.6, color= 'orchid', label='Second S')

axs[1].plot(t, a_1_n_mrt, linewidth=0.6, color = 'darkgreen', label='Basement N')
axs[1].plot(t, a_1_s_mrt, linewidth=0.6, color= 'chartreuse', label='Basement S')
axs[1].plot(t, a_2_n_mrt, linewidth=0.6, color= 'mediumblue', label='First N')
axs[1].plot(t, a_2_s_mrt, linewidth=0.6, color= 'cornflowerblue', label='First S')
axs[1].plot(t, a_3_n_mrt, linewidth=0.6, color= 'darkviolet', label='Second N')
axs[1].plot(t, a_3_s_mrt, linewidth=0.6, color= 'orchid', label='Second S')

axs[2].plot(t, a_o_rh, linewidth=2, linestyle='dashed', label='Outdoor')
axs[2].plot(t, a_1_n_rh, linewidth=0.6, color = 'darkgreen', label='Basement N')
axs[2].plot(t, a_1_s_rh, linewidth=0.6, color= 'chartreuse', label='Basement S')
axs[2].plot(t, a_2_n_rh, linewidth=0.6, color= 'mediumblue', label='First N')
axs[2].plot(t, a_2_s_rh, linewidth=0.6, color= 'cornflowerblue', label='First S')
axs[2].plot(t, a_3_n_rh, linewidth=0.6, color= 'darkviolet', label='Second N')
axs[2].plot(t, a_3_s_rh, linewidth=0.6, color= 'orchid', label='Second S')

# axs[0].set_xlim(0, 2)
# axs[0].set_xlabel('Date')
# axs[1].set_xlabel('Date')
axs[2].set_xlabel('Date')
axs[0].set_ylabel('Temperature [°C]')
axs[1].set_ylabel('RadiantTemperature [°C]')
axs[2].set_ylabel('Relative Humidity [%]')
axs[0].grid(True)
axs[1].grid(True)
axs[2].grid(True)
axs[0].legend(loc='lower left', fontsize=6)
axs[1].legend(loc='lower left', fontsize=6)
axs[2].legend(loc='lower left', fontsize=6)
axs[0].tick_params(labelbottom=False)
axs[1].tick_params(labelbottom=False)


plt.setp(axs[2].xaxis.get_majorticklabels(), rotation=30)
plt.suptitle('House A')
plt.show()

# %%
df_a = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_A_Complete Data_outage.xlsx")
df_t = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_T_Complete Data_outage.xlsx")
df_r = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_R_Complete Data_outage.xlsx")

t_a = df_a['Date-Time (CDT)']
a_o_t = df_a['A_O_T [°C]']
a_1_n_t = df_a['A_1_N_T  [°C]']
a_1_s_t = df_a['A_1_S_T  [°C]']
a_2_n_t = df_a['A_2_N_T  [°C]']
a_2_s_t = df_a['A_2_S_T  [°C]']
a_3_n_t = df_a['A_3_N_T  [°C]']
a_3_s_t = df_a['A_3_S_T  [°C]']

t_r = df_r['Date-Time (CDT)']
r_o_t = df_r['R_O_T [°C]']
r_1_n_t = df_r['R_1_W_T  [°C]']
r_1_s_t = df_r['R_1_E_T  [°C]']
r_2_n_t = df_r['R_2_W_T  [°C]']
r_2_s_t = df_r['R_2_E_T  [°C]']
r_3_n_t = df_r['R_3_W_T  [°C]']
r_3_s_t = df_r['R_3_E_T  [°C]']


t_t = df_t['Date-Time (CDT)']
t_o_t = df_t['T_O_T [°C]']
t_1_n_t = df_t['T_1_W_T  [°C]']
t_1_s_t = df_t['T_1_E_T  [°C]']
t_2_n_t = df_t['T_2_W_T  [°C]']
t_2_s_t = df_t['T_2_E_T  [°C]']
t_3_n_t = df_t['T_3_W_T  [°C]']
t_3_s_t = df_t['T_3_E_T  [°C]']






fig, axs = plt.subplots(1, 3, layout='constrained', figsize=(8,4))

axs[0].plot(t_a, a_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[0].plot(t_a, a_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement N')
axs[0].plot(t_a, a_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement S')
axs[0].plot(t_a, a_2_n_t, linewidth=0.6, color= 'mediumblue', label='First N')
axs[0].plot(t_a, a_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First S')
axs[0].plot(t_a, a_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second N')
axs[0].plot(t_a, a_3_s_t, linewidth=0.6, color= 'orchid', label='Second S')



axs[1].plot(t_r, r_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[1].plot(t_r, r_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[1].plot(t_r, r_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[1].plot(t_r, r_2_n_t, linewidth=0.6, color= 'mediumblue', label='First W')
axs[1].plot(t_r, r_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[1].plot(t_r, r_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[1].plot(t_r, r_3_s_t, linewidth=0.6, color= 'orchid', label='Second E')



axs[2].plot(t_t, t_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[2].plot(t_t, t_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[2].plot(t_t, t_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[2].plot(t_t, t_2_n_t, linewidth=0.6, color= 'mediumblue', label='First W')
axs[2].plot(t_t, t_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[2].plot(t_t, t_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[2].plot(t_t, t_3_s_t, linewidth=0.6, color= 'orchid', label='Second E')




axs[0].set_ylim(-5, 25)
axs[1].set_ylim(-5, 25)
axs[2].set_ylim(-5, 25)
axs[0].set_xlabel('Date')
axs[1].set_xlabel('Date')
axs[2].set_xlabel('Date')
axs[0].set_ylabel('Temperature [°C]')
# axs[1].set_ylabel('RadiantTemperature [°C]')
# axs[2].set_ylabel('Relative Humidity [%]')
axs[0].grid(True)
axs[1].grid(True)
axs[2].grid(True)
axs[0].legend(loc='lower left', fontsize=6)
# axs[1].legend(loc='lower left', fontsize=6)
axs[2].legend(loc='lower left', fontsize=6)
# axs[0].tick_params(labelbottom=False)
# axs[1].tick_params(labelbottom=False)

axs[0].set_title("House A")
axs[1].set_title("House R")
axs[2].set_title("House T")


plt.setp(axs[0].xaxis.get_majorticklabels(), rotation=30)
plt.setp(axs[1].xaxis.get_majorticklabels(), rotation=30)
plt.setp(axs[2].xaxis.get_majorticklabels(), rotation=30)

plt.suptitle('Temperature During Outage')
plt.show()

# %%
df_a = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_A_Complete Data_outage.xlsx")
df_t = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_T_Complete Data_outage.xlsx")
df_r = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_R_Complete Data_outage.xlsx")

t_a = df_a['Date-Time (CDT)']
a_o_t = df_a['A_O_T [°C]']
a_1_n_t = df_a['A_1_N_MRT  [°C]']
a_1_s_t = df_a['A_1_S_MRT  [°C]']
a_2_n_t = df_a['A_2_N_MRT  [°C]']
a_2_s_t = df_a['A_2_S_MRT  [°C]']
a_3_n_t = df_a['A_3_N_MRT  [°C]']
a_3_s_t = df_a['A_3_S_MRT  [°C]']

t_r = df_r['Date-Time (CDT)']
r_o_t = df_r['R_O_T [°C]']
r_1_n_t = df_r['R_1_W_MRT  [°C]']
r_1_s_t = df_r['R_1_E_MRT  [°C]']
r_2_n_t = df_r['R_2_W_MRT  [°C]']
r_2_s_t = df_r['R_2_E_MRT  [°C]']
r_3_n_t = df_r['R_3_W_MRT  [°C]']
r_3_s_t = df_r['R_3_E_MRT  [°C]']


t_t = df_t['Date-Time (CDT)']
t_o_t = df_t['T_O_T [°C]']
t_1_n_t = df_t['T_1_W_MRT  [°C]']
t_1_s_t = df_t['T_1_E_MRT  [°C]']
t_2_n_t = df_t['T_2_W_MRT  [°C]']
t_2_s_t = df_t['T_2_E_MRT  [°C]']
t_3_n_t = df_t['T_3_W_MRT  [°C]']
t_3_s_t = df_t['T_3_E_MRT  [°C]']






fig, axs = plt.subplots(1, 3, layout='constrained', figsize=(8,4))

axs[0].plot(t_a, a_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[0].plot(t_a, a_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement N')
axs[0].plot(t_a, a_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement S')
axs[0].plot(t_a, a_2_n_t, linewidth=0.6, color= 'mediumblue', label='First N')
axs[0].plot(t_a, a_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First S')
axs[0].plot(t_a, a_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second N')
axs[0].plot(t_a, a_3_s_t, linewidth=0.6, color= 'orchid', label='Second S')



axs[1].plot(t_r, r_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[1].plot(t_r, r_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[1].plot(t_r, r_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[1].plot(t_r, r_2_n_t, linewidth=0.6, color= 'mediumblue', label='First W')
axs[1].plot(t_r, r_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[1].plot(t_r, r_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[1].plot(t_r, r_3_s_t, linewidth=0.6, color= 'orchid', label='Second E')



axs[2].plot(t_t, t_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[2].plot(t_t, t_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[2].plot(t_t, t_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[2].plot(t_t, t_2_n_t, linewidth=0.6, color= 'mediumblue', label='First W')
axs[2].plot(t_t, t_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[2].plot(t_t, t_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[2].plot(t_t, t_3_s_t, linewidth=0.6, color= 'orchid', label='Second E')




axs[0].set_ylim(-5, 25)
axs[1].set_ylim(-5, 25)
axs[2].set_ylim(-5, 25)
axs[0].set_xlabel('Date')
axs[1].set_xlabel('Date')
axs[2].set_xlabel('Date')
axs[0].set_ylabel('Mean Radiant Temperature [°C]')
# axs[1].set_ylabel('RadiantTemperature [°C]')
# axs[2].set_ylabel('Relative Humidity [%]')
axs[0].grid(True)
axs[1].grid(True)
axs[2].grid(True)
axs[0].legend(loc='lower left', fontsize=6)
# axs[1].legend(loc='lower left', fontsize=6)
axs[2].legend(loc='lower left', fontsize=6)
# axs[0].tick_params(labelbottom=False)
# axs[1].tick_params(labelbottom=False)

axs[0].set_title("House A")
axs[1].set_title("House R")
axs[2].set_title("House T")


plt.setp(axs[0].xaxis.get_majorticklabels(), rotation=30)
plt.setp(axs[1].xaxis.get_majorticklabels(), rotation=30)
plt.setp(axs[2].xaxis.get_majorticklabels(), rotation=30)

plt.suptitle('Mean Radiant Temperature During Outage')
plt.show()

# %%
df_a = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_A_Complete Data_outage.xlsx")
df_t = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_T_Complete Data_outage.xlsx")
df_r = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_R_Complete Data_outage.xlsx")

t_a = df_a['Date-Time (CDT)']
a_o_t = df_a['A_O_T [°C]']
a_1_n_t = df_a['A_1_N_MRT  [°C]']
a_1_s_t = df_a['A_1_S_MRT  [°C]']
a_2_n_t = df_a['A_2_N_MRT  [°C]']
a_2_s_t = df_a['A_2_S_MRT  [°C]']
a_3_n_t = df_a['A_3_N_MRT  [°C]']
a_3_s_t = df_a['A_3_S_MRT  [°C]']

t_r = df_r['Date-Time (CDT)']
r_o_t = df_r['R_O_T [°C]']
r_1_n_t = df_r['R_1_W_MRT  [°C]']
r_1_s_t = df_r['R_1_E_MRT  [°C]']
r_2_n_t = df_r['R_2_W_MRT  [°C]']
r_2_s_t = df_r['R_2_E_MRT  [°C]']
r_3_n_t = df_r['R_3_W_MRT  [°C]']
r_3_s_t = df_r['R_3_E_MRT  [°C]']


t_t = df_t['Date-Time (CDT)']
t_o_t = df_t['T_O_T [°C]']
t_1_n_t = df_t['T_1_W_MRT  [°C]']
t_1_s_t = df_t['T_1_E_MRT  [°C]']
t_2_n_t = df_t['T_2_W_MRT  [°C]']
t_2_s_t = df_t['T_2_E_MRT  [°C]']
t_3_n_t = df_t['T_3_W_MRT  [°C]']
t_3_s_t = df_t['T_3_E_MRT  [°C]']






fig, axs = plt.subplots(1, 3, layout='constrained', figsize=(8,4))

axs[0].plot(t_a, a_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[0].plot(t_a, a_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement N')
axs[0].plot(t_a, a_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement S')
axs[0].plot(t_a, a_2_n_t, linewidth=0.6, color= 'mediumblue', label='First N')
axs[0].plot(t_a, a_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First S')
axs[0].plot(t_a, a_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second N')
axs[0].plot(t_a, a_3_s_t, linewidth=0.6, color= 'orchid', label='Second S')



axs[1].plot(t_r, r_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[1].plot(t_r, r_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[1].plot(t_r, r_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[1].plot(t_r, r_2_n_t, linewidth=0.6, color= 'mediumblue', label='First W')
axs[1].plot(t_r, r_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[1].plot(t_r, r_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[1].plot(t_r, r_3_s_t, linewidth=0.6, color= 'orchid', label='Second E')



axs[2].plot(t_t, t_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[2].plot(t_t, t_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[2].plot(t_t, t_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[2].plot(t_t, t_2_n_t, linewidth=0.6, color= 'mediumblue', label='First W')
axs[2].plot(t_t, t_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[2].plot(t_t, t_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[2].plot(t_t, t_3_s_t, linewidth=0.6, color= 'orchid', label='Second E')




axs[0].set_ylim(-5, 25)
axs[1].set_ylim(-5, 25)
axs[2].set_ylim(-5, 25)
axs[0].set_xlabel('Date')
axs[1].set_xlabel('Date')
axs[2].set_xlabel('Date')
axs[0].set_ylabel('Mean Radiant Temperature [°C]')
# axs[1].set_ylabel('RadiantTemperature [°C]')
# axs[2].set_ylabel('Relative Humidity [%]')
axs[0].grid(True)
axs[1].grid(True)
axs[2].grid(True)
axs[0].legend(loc='lower left', fontsize=6)
# axs[1].legend(loc='lower left', fontsize=6)
axs[2].legend(loc='lower left', fontsize=6)
# axs[0].tick_params(labelbottom=False)
# axs[1].tick_params(labelbottom=False)

axs[0].set_title("House A")
axs[1].set_title("House R")
axs[2].set_title("House T")


plt.setp(axs[0].xaxis.get_majorticklabels(), rotation=30)
plt.setp(axs[1].xaxis.get_majorticklabels(), rotation=30)
plt.setp(axs[2].xaxis.get_majorticklabels(), rotation=30)

plt.suptitle('Mean Radiant Temperature During Outage')
plt.show()

# %%
df_a = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_A_Complete Data_outage.xlsx")
df_t = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_T_Complete Data_outage.xlsx")
df_r = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_R_Complete Data_outage.xlsx")

t_a = df_a['Date-Time (CDT)']
a_o_t = df_a['A_O_T [°C]']
a_1_n_t = df_a['A_1_N_MRT  [°C]']
a_1_s_t = df_a['A_1_S_MRT  [°C]']
a_2_n_t = df_a['A_2_N_MRT  [°C]']
a_2_s_t = df_a['A_2_S_MRT  [°C]']
a_3_n_t = df_a['A_3_N_MRT  [°C]']
a_3_s_t = df_a['A_3_S_MRT  [°C]']

t_r = df_r['Date-Time (CDT)']
r_o_t = df_r['R_O_T [°C]']
r_1_n_t = df_r['R_1_W_MRT  [°C]']
r_1_s_t = df_r['R_1_E_MRT  [°C]']
r_2_n_t = df_r['R_2_W_MRT  [°C]']
r_2_s_t = df_r['R_2_E_MRT  [°C]']
r_3_n_t = df_r['R_3_W_MRT  [°C]']
r_3_s_t = df_r['R_3_E_MRT  [°C]']


t_t = df_t['Date-Time (CDT)']
t_o_t = df_t['T_O_T [°C]']
t_1_n_t = df_t['T_1_W_MRT  [°C]']
t_1_s_t = df_t['T_1_E_MRT  [°C]']
t_2_n_t = df_t['T_2_W_MRT  [°C]']
t_2_s_t = df_t['T_2_E_MRT  [°C]']
t_3_n_t = df_t['T_3_W_MRT  [°C]']
t_3_s_t = df_t['T_3_E_MRT  [°C]']






fig, axs = plt.subplots(1, 3, layout='constrained', figsize=(8,4))

axs[0].plot(t_a, a_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[0].plot(t_a, a_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement N')
axs[0].plot(t_a, a_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement S')
axs[0].plot(t_a, a_2_n_t, linewidth=0.6, color= 'mediumblue', label='First N')
axs[0].plot(t_a, a_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First S')
axs[0].plot(t_a, a_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second N')
axs[0].plot(t_a, a_3_s_t, linewidth=0.6, color= 'orchid', label='Second S')



axs[1].plot(t_r, r_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[1].plot(t_r, r_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[1].plot(t_r, r_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[1].plot(t_r, r_2_n_t, linewidth=0.6, color= 'mediumblue', label='First W')
axs[1].plot(t_r, r_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[1].plot(t_r, r_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[1].plot(t_r, r_3_s_t, linewidth=0.6, color= 'orchid', label='Second E')



axs[2].plot(t_t, t_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[2].plot(t_t, t_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[2].plot(t_t, t_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[2].plot(t_t, t_2_n_t, linewidth=0.6, color= 'mediumblue', label='First W')
axs[2].plot(t_t, t_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[2].plot(t_t, t_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[2].plot(t_t, t_3_s_t, linewidth=0.6, color= 'orchid', label='Second E')




axs[0].set_ylim(-5, 25)
axs[1].set_ylim(-5, 25)
axs[2].set_ylim(-5, 25)
axs[0].set_xlabel('Date')
axs[1].set_xlabel('Date')
axs[2].set_xlabel('Date')
axs[0].set_ylabel('Mean Radiant Temperature [°C]')
# axs[1].set_ylabel('RadiantTemperature [°C]')
# axs[2].set_ylabel('Relative Humidity [%]')
axs[0].grid(True)
axs[1].grid(True)
axs[2].grid(True)
axs[0].legend(loc='lower left', fontsize=6)
# axs[1].legend(loc='lower left', fontsize=6)
axs[2].legend(loc='lower left', fontsize=6)
# axs[0].tick_params(labelbottom=False)
# axs[1].tick_params(labelbottom=False)

axs[0].set_title("House A")
axs[1].set_title("House R")
axs[2].set_title("House T")


plt.setp(axs[0].xaxis.get_majorticklabels(), rotation=30)
plt.setp(axs[1].xaxis.get_majorticklabels(), rotation=30)
plt.setp(axs[2].xaxis.get_majorticklabels(), rotation=30)

plt.suptitle('Mean Radiant Temperature During Outage')
plt.show()

# %%
df = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_T_Complete Data.xlsx")

t = df['Date-Time (CDT)']
t_o_t = df['T_O_T [°C]']
t_1_n_t = df['T_1_W_T  [°C]']
t_1_s_t = df['T_1_E_T  [°C]']
t_2_n_t = df['T_2_W_T  [°C]']
t_2_s_t = df['T_2_E_T  [°C]']
t_3_n_t = df['T_3_W_T  [°C]']
t_3_s_t = df['T_3_E_T  [°C]']


t_1_n_mrt = df['T_1_W_MRT  [°C]']
t_1_s_mrt = df['T_1_E_MRT  [°C]']
t_2_n_mrt = df['T_2_W_MRT  [°C]']
t_2_s_mrt = df['T_2_E_MRT  [°C]']
t_3_n_mrt = df['T_3_W_MRT  [°C]']
t_3_s_mrt = df['T_3_E_MRT  [°C]']

t_o_rh = df['T_O_RH [%]']
t_1_n_rh = df['T_1_W_RH  [%]']
t_1_s_rh = df['T_1_E_RH  [%]']
t_2_n_rh = df['T_2_W_RH  [%]']
t_2_s_rh = df['T_2_E_RH  [%]']
t_3_n_rh = df['T_3_W_RH  [%]']
t_3_s_rh = df['T_3_E_RH  [%]']

fig, axs = plt.subplots(3, 1, layout='constrained', figsize=(6,8))
axs[0].plot(t, t_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[0].plot(t, t_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[0].plot(t, t_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[0].plot(t, t_2_n_t, linewidth=0.6, color= 'mediumblue', label='First W')
axs[0].plot(t, t_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[0].plot(t, t_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[0].plot(t, t_3_s_t, linewidth=0.6, color= 'orchid', label='Second E')

axs[1].plot(t, t_1_n_mrt, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[1].plot(t, t_1_s_mrt, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[1].plot(t, t_2_n_mrt, linewidth=0.6, color= 'mediumblue', label='First W')
axs[1].plot(t, t_2_s_mrt, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[1].plot(t, t_3_n_mrt, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[1].plot(t, t_3_s_mrt, linewidth=0.6, color= 'orchid', label='Second E')

axs[2].plot(t, t_o_rh, linewidth=2, linestyle='dashed', label='Outdoor')
axs[2].plot(t, t_1_n_rh, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[2].plot(t, t_1_s_rh, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[2].plot(t, t_2_n_rh, linewidth=0.6, color= 'mediumblue', label='First W')
axs[2].plot(t, t_2_s_rh, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[2].plot(t, t_3_n_rh, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[2].plot(t, t_3_s_rh, linewidth=0.6, color= 'orchid', label='Second E')

# axs[0].set_xlim(0, 2)
# axs[0].set_xlabel('Date')
# axs[1].set_xlabel('Date')
axs[2].set_xlabel('Date')
axs[0].set_ylabel('Temperature [°C]')
axs[1].set_ylabel('RadiantTemperature [°C]')
axs[2].set_ylabel('Relative Humidity [%]')
axs[0].grid(True)
axs[1].grid(True)
axs[2].grid(True)
axs[0].legend(loc='lower left', fontsize=6)
axs[1].legend(loc='lower left', fontsize=6)
axs[2].legend(loc='lower left', fontsize=6)
axs[0].tick_params(labelbottom=False)
axs[1].tick_params(labelbottom=False)


plt.setp(axs[2].xaxis.get_majorticklabels(), rotation=30)

plt.suptitle('House T')
plt.show()

# %%
df = pd.read_excel("D:/School/IIT-PHD/FIeld Study/Data/0_R_Complete Data.xlsx")

t = df['Date-Time (CDT)']
r_o_t = df['R_O_T [°C]']
r_1_n_t = df['R_1_W_T  [°C]']
r_1_s_t = df['R_1_E_T  [°C]']
r_2_n_t = df['R_2_W_T  [°C]']
r_2_s_t = df['R_2_E_T  [°C]']
r_3_n_t = df['R_3_W_T  [°C]']
r_3_s_t = df['R_3_E_T  [°C]']


r_1_n_mrt = df['R_1_W_MRT  [°C]']
r_1_s_mrt = df['R_1_E_MRT  [°C]']
r_2_n_mrt = df['R_2_W_MRT  [°C]']
r_2_s_mrt = df['R_2_E_MRT  [°C]']
r_3_n_mrt = df['R_3_W_MRT  [°C]']
r_3_s_mrt = df['R_3_E_MRT  [°C]']

r_o_rh = df['R_O_RH [%]']
r_1_n_rh = df['R_1_W_RH  [%]']
r_1_s_rh = df['R_1_E_RH  [%]']
r_2_n_rh = df['R_2_W_RH  [%]']
r_2_s_rh = df['R_2_E_RH  [%]']
r_3_n_rh = df['R_3_W_RH  [%]']
r_3_s_rh = df['R_3_E_RH  [%]']

fig, axs = plt.subplots(3, 1, layout='constrained', figsize=(6,8))
axs[0].plot(t, r_o_t, linewidth=2, linestyle='dashed', label='Outdoor')
axs[0].plot(t, r_1_n_t, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[0].plot(t, r_1_s_t, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[0].plot(t, r_2_n_t, linewidth=0.6, color= 'mediumblue', label='First W')
axs[0].plot(t, r_2_s_t, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[0].plot(t, r_3_n_t, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[0].plot(t, r_3_s_t, linewidth=0.6, color= 'orchid', label='Second E')

axs[1].plot(t, r_1_n_mrt, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[1].plot(t, r_1_s_mrt, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[1].plot(t, r_2_n_mrt, linewidth=0.6, color= 'mediumblue', label='First W')
axs[1].plot(t, r_2_s_mrt, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[1].plot(t, r_3_n_mrt, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[1].plot(t, r_3_s_mrt, linewidth=0.6, color= 'orchid', label='Second E')

axs[2].plot(t, r_o_rh, linewidth=2, linestyle='dashed', label='Outdoor')
axs[2].plot(t, r_1_n_rh, linewidth=0.6, color = 'darkgreen', label='Basement W')
axs[2].plot(t, r_1_s_rh, linewidth=0.6, color= 'chartreuse', label='Basement E')
axs[2].plot(t, r_2_n_rh, linewidth=0.6, color= 'mediumblue', label='First W')
axs[2].plot(t, r_2_s_rh, linewidth=0.6, color= 'cornflowerblue', label='First E')
axs[2].plot(t, r_3_n_rh, linewidth=0.6, color= 'darkviolet', label='Second W')
axs[2].plot(t, r_3_s_rh, linewidth=0.6, color= 'orchid', label='Second E')

# axs[0].set_xlim(0, 2)
# axs[0].set_xlabel('Date')
# axs[1].set_xlabel('Date')
axs[2].set_xlabel('Date')
axs[0].set_ylabel('Temperature [°C]')
axs[1].set_ylabel('RadiantTemperature [°C]')
axs[2].set_ylabel('Relative Humidity [%]')
axs[0].grid(True)
axs[1].grid(True)
axs[2].grid(True)
axs[0].legend(loc='lower left', fontsize=6)
axs[1].legend(loc='lower left', fontsize=6)
axs[2].legend(loc='lower left', fontsize=6)

axs[0].tick_params(labelbottom=False)
axs[1].tick_params(labelbottom=False)


plt.setp(axs[2].xaxis.get_majorticklabels(), rotation=30)
plt.suptitle('House R')
plt.show()
