# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('data.csv')
df = df.drop(columns=['Case', 'Source Energy [kWh/person yr]'])


labels = list(df.columns)
asDesigned = list(df.iloc[1])
targets = list(df.iloc[0])
phius = list(df.iloc[2])

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(6.5,6.5))
rects1 = ax.bar(x - width/2, asDesigned, width, label='As Designed')
rects2 = ax.bar(x + width/2, phius, width, label='Phius 2021')


# Add some text for labels, title and custom x-axis tick labels, etc.
#ax.set_ylabel('Scores')
ax.set_title('Space Conditioning Targets')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=30)
ax.legend()

for z in np.arange(len(targets)):
    ax.axhline(y=targets[z], xmin=(z*(1/len(targets))), xmax=((1/len(targets))+(z*(1/len(targets)))), color='black')




ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %%
df2 = pd.read_csv('data2.csv')
df2 = df2.drop(columns=['Use'])
df2cols = list(df2.columns)
width = 0.35 
x = []
x = ['As Designed', 'Phius 2021']
fig, ax = plt.subplots(figsize=(6.5,6.5))
ax.set_title('Site Energy End Uses')


heating = ax.bar(df2cols, df2.iloc[0], width, label=('Space Heating'), color='red')
ax.bar_label(heating, padding=-15)
cooling = ax.bar(df2cols, df2.iloc[1], width, label=('Space Cooling'), color='blue', bottom=df2.iloc[0])
ax.bar_label(cooling, padding=-15)
dhw= ax.bar(df2cols, df2.iloc[2], width, label=('Hot Water'), color='green', bottom=df2.iloc[0]+df2.iloc[1])
ax.bar_label(dhw, padding=-15)
aux= ax.bar(df2cols, df2.iloc[3], width, label=('Auxilary Energy / Fans'), color='pink', bottom=df2.iloc[0]+df2.iloc[1]+df2.iloc[2])
ax.bar_label(aux, padding=-15)
app= ax.bar(df2cols, df2.iloc[4], width, label=('Large Appliances'), bottom=df2.iloc[0]+df2.iloc[1]+df2.iloc[2]+df2.iloc[3])
ax.bar_label(app, padding=-15)
lit= ax.bar(df2cols, df2.iloc[5], width, label=('Lighting'), color='yellow', bottom=df2.iloc[0]+df2.iloc[1]+df2.iloc[2]+df2.iloc[3]+df2.iloc[4])
ax.bar_label(lit, padding=-15)
mel= ax.bar(df2cols, df2.iloc[6], width, label=('MELs'), color='purple', bottom=df2.iloc[0]+df2.iloc[1]+df2.iloc[2]+df2.iloc[3]+df2.iloc[4]+df2.iloc[5])
ax.bar_label(mel, padding=-15)

#ax.set_xticks(x)
#ax.set_xticklabels(labels, rotation=30)
ax.legend()
ax.set_ylabel('Site Energy [kWh/yr]')


plt.show()
